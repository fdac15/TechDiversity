# %%
# Read MDPI from 
import json, pymongo, sys, pprint

client = pymongo.MongoClient(host="da0.eecs.utk.edu")
db = client["TechDiversity"]
coll = db["mdpi"]

pp = pprint.PrettyPrinter(indent=4)

for r in coll.find({}):
    pp.pprint(r)
# Out:
# {   '_id': ObjectId('564a361d8fc78c00fa2d9dd6'),
#     'author': 'Hristo Djidjev',
#     'date': ' 9 October 2015',
#     'isbn': '10.3390/a8040850',
#     'title': 'Automatic Classification of Protein Structure Using the '
#              'Maximum Contact Map Overlap Metric',
#     'university': 'Los Alamos National Laboratory, Los Alamos, NM 87544, USA'}
# {   '_id': ObjectId('564a361d8fc78c00fa2d9dd7'),
#     'author': 'Ioannis K. Argyros',
#     'date': ' 9 October 2015',
#     'isbn': '10.3390/a8040832',
#     'title': 'Newton-Type Methods on Generalized Banach Spaces and '
#              'Applications in Fractional Calculus',
#     'university': 'Department of Mathematics Sciences, Cameron University, '
#                   'Lawton, OK 73505, USA'}
# {   '_id': ObjectId('564a361d8fc78c00fa2d9dd8'),
#     'author': 'Ioannis K. Argyros',
#     'date': ' 19 August 2015',
#     'isbn': '10.3390/a8030645',
# ...
